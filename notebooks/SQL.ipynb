# %%
# %%sql
#
# select * from demo.bsc.transactions order by block_number limit 10;
# Out:
# +--------------------------------------------------------------------+-------+--------------------------------------------------------------------+--------------+-----------------+-------------------+--------------------------------------------+--------------------------------------------+-------+---------------------+-----------+----------------------------------------------------------------------------+-----------------+--------------------------+------------------+
# |                                                               hash | nonce |                                                         block_hash | block_number | block_timestamp | transaction_index |                               from_address |                                 to_address | value |                 gas | gas_price |                                                                      input | max_fee_per_gas | max_priority_fee_per_gas | transaction_type |
# ...
